# %%
from models import orbit_model_campbell
import numpy as np

# %%
t = np.linspace(0, 100, 100)
csst_pos = np.zeros((100, 3))
csst_v = np.zeros((100, 3))
u = np.array([1,0,0])

from functions import plot_model
params = [
    0, 0, 0, 0, 100, # ra_com_0, dec_com_0, pmra, pmdec, plx,
    100, 0.8, 10, # period, ecc, semi_maj
    np.pi/2, np.pi/2, np.pi/2, 0  # incl, arg_peri, omega, m_0
]
plot_model(orbit_model_campbell, params, t, csst_pos, csst_v, u, plot_pred=True)
